# %% [markdown]
# # MonteCarlo Simulation
# In this notebook we cover a full example using MonteCarlo Simulation.

# %%
# install all the azure kusto modules
# %pip install azure.kusto.data
# %pip install azure-kusto-ingest
# %pip install azure.identity
# %pip install pandas

# %%
# install all the azure kusto modules
# %pip install pyodbc
# Out:
# Collecting pyodbc
#   Downloading pyodbc-5.1.0-cp311-cp311-win_amd64.whl (68 kB)
#                                               0.0/68.7 kB ? eta -:--:--
#      -----                                    10.2/68.7 kB ? eta -:--:--
#      ----------------                       30.7/68.7 kB 217.9 kB/s eta 0:00:01
#      ---------------------------------      61.4/68.7 kB 363.1 kB/s eta 0:00:01
#      -------------------------------------- 68.7/68.7 kB 372.6 kB/s eta 0:00:00
# Installing collected packages: pyodbc
# Successfully installed pyodbc-5.1.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from azure.kusto.data import KustoClient, KustoConnectionStringBuilder, ClientRequestProperties
from azure.identity import AzureCliCredential, ChainedTokenCredential, DefaultAzureCredential, ManagedIdentityCredential
from azure.kusto.data.exceptions import KustoServiceError
from azure.kusto.data.helpers import dataframe_from_result_table
import pandas as pd
import json

class KustoConnection():
    def __init__(self, configuration : dict):
        uri = configuration.get('cluster_uri')
        if (not str(uri).startswith('https://')):
            uri = "https://" + uri
        if (not str(uri).endswith('.kusto.windows.net')) :
            uri = uri + '.kusto.windows.net'
        self.cluster_uri = uri
        self.database = configuration.get('database')
        cred = ChainedTokenCredential(ManagedIdentityCredential(), AzureCliCredential(), DefaultAzureCredential())
        connection_string = KustoConnectionStringBuilder.with_aad_application_token_authentication(self.cluster_uri, 
                                                                                                   cred.get_token(self.cluster_uri + '/.default').token)        
        # Create a KustoClient instance
        self.client = KustoClient(connection_string)

    def query(self, query: str, properties: ClientRequestProperties = None) -> pd.DataFrame:
        """
        Execute a Kusto query.
        @param query: The query.
        @returns: A Pandas DataFrame.
        """
        response = self.client.execute_query(self.database, query, properties)
        df = dataframe_from_result_table(response.primary_results[0])
        return df

    def get_schema(self, table_name: str) -> dict:
        """
        Get a table schema
        @param table_name: name of table
        @returns a dictionary mapping column names to kusto types
        """
        schema = self.client.execute_mgmt(self.database, f".show table {table_name} schema as json").primary_results[0][0]['Schema']
        return json.loads(schema)

    def close(self):
        """
        Close the Kusto client.
        """
        self.client.close()

from azure.identity import AzureCliCredential, ChainedTokenCredential, DefaultAzureCredential, ManagedIdentityCredential
import struct
import pyodbc
import pandas as pd 

class DatabaseConnection():
    def __init__(self, configuration : dict):
        server = configuration.get('server')
        if (not str(server).endswith('.database.windows.net')) :
            server = server + '.database.windows.net';
        self.sever = server;
        self.database = configuration.get('database');

        self.server = 'eppmreportingdev.database.windows.net';
        self.database = 'DCEPDev';
        query = 'SELECT TOP 10 * from [MonteCarlo].[SimulationResult];'
        credential = ChainedTokenCredential(ManagedIdentityCredential(), 
                                            AzureCliCredential(), 
                                            DefaultAzureCredential());
        databaseToken = credential.get_token('https://database.windows.net/');
        tokenb = bytes(databaseToken[0], "UTF-8");
        exptoken = b'';
        for i in tokenb:
            exptoken += bytes({i});
            exptoken += bytes(1);
        tokenstruct = struct.pack("=i", len(exptoken)) + exptoken;
        connString = "Driver={ODBC Driver 17 for SQL Server};SERVER="+self.sever+";DATABASE="+self.database+"";
        SQL_COPT_SS_ACCESS_TOKEN = 1256; 
        self.connection = pyodbc.connect(connString, attrs_before = {SQL_COPT_SS_ACCESS_TOKEN:tokenstruct});


    # write a database to database, mode = append or replace
    def insert(self, df : pd.DataFrame, table :str):
        """
        Execute a SQL write.
        @param df: Data Frame.        
        @param table: Table Name.
        """
        statement = '''
        INSERT INTO {table}
        (
            {columns}
        )
        VALUES({place_holders})
        '''
        # add protection on column name
        columns = df.columns.tolist();
        for i in range(len(columns)):
            columns[i] = '[' + columns[i] + ']';
        statement = statement.format(table = table, 
                                     columns = (',').join(columns), 
                                     place_holders = (',').join(['?'] * len(df.columns)));
        print(statement);
        # Create a Pandas dataframe from the results
        cursor = self.connection.cursor();
        cursor.executemany(statement, df.values.tolist());
        cursor.commit();
        cursor.close();

    # execute sql command
    def execute(self, statement : str):
        """
        Execute a SQL command.
        @param query: query.        
        """
        # Create a Pandas dataframe from the results
        cursor = self.connection.cursor();
        cursor.execute(statement);
        cursor.commit();
        cursor.close();


    def query(self, query: str) -> pd.DataFrame:
        """
        Execute a SQL query.
        @param query: The query.
        @returns: A Pandas DataFrame.
        """
        # Create a Pandas dataframe from the results
        
        df = pd.read_sql(query, self.connection);

        # Print the dataframe
        print(df);
        return df

    def close(self):
        """
        Close the Database client.
        """
        self.connection.close();

class DCEPKustoData():
    def __init__(self):
        self.kusto_client = KustoConnection({'cluster_uri' : "dpxedwhprod.southcentralus", 'database': "Dpxedwhprod"});
        self.query = {
        'IFP_CS_FS_IST_CR_Tranche_List' : 
        '''
        DCEPAllMilestonesCurrent
        | where ProjectType in ("Build","Build PH","OAI Build") 
        | summarize by ProjectName, Tranche
        | join kind = leftouter
        (
            DCEPAllMilestonesCurrent 
            | summarize by DCShortCode, ProjectName, Tranche, 
                Colo_Ready_L2Milestone = "Colo Ready", 
                ProjectType, 
                CR_TaskStartDate = ColoReadyDate, 
                CR_TaskFinishDate = ColoReadyDate 
        )
        on $left.ProjectName == $right.ProjectName and $left.Tranche == $right.Tranche
        | project-away ProjectName1, Tranche1        
        | join kind = leftouter
        (
            DCEPAllMilestonesCurrent 
            | where Tranche == 1 and ProjectType in ("Build","Build PH","OAI Build") 
            | summarize by DCShortCode, ProjectName, Tranche, 
                Design_IFP_Milestone = "Design IFP", 
                ProjectType, 
                IFP_TaskStartDate = DesignIFP, 
                IFP_TaskFinishDate = DesignIFP        
        )
        on $left.ProjectName == $right.ProjectName
        | project-away DCShortCode1, ProjectName1, ProjectType1, Tranche1          
        | join kind = leftouter
        (
            DCEPAllMilestonesCurrent 
              | where Tranche == 1 and ProjectType in ("Build","Build PH","OAI Build") 
              | summarize by DCShortCode, ProjectName,
                    Tranche, CS_L2Milestone = "Construction Start", 
                    ProjectType, CS_TaskStartDate = ConstructionDate, 
                    CS_TaskFinishDate = ConstructionDate            
        )
        on $left.ProjectName == $right.ProjectName 
        | project-away DCShortCode1, ProjectName1, ProjectType1, Tranche1  
        | join kind = leftouter
        (
            EstimatedFoundationStart
            | summarize by 
                DCShortCode, ProjectName, Tranche = tostring(Tranche), 
                FS_L2Milestone="Foundation", ProjectType, 
                FS_TaskStartDate = Foudation_TaskStartDate, 
                FS_TaskFinishDate = Foudation_TaskFinishDate
        )
        on $left.ProjectName == $right.ProjectName and $left.Tranche == $right.Tranche
        | project-away DCShortCode1, ProjectName1, ProjectType1, Tranche1 
        | join kind = leftouter
        (
            DCEPAllMilestonesCurrent 
            | where ProjectType in ("Build","Build PH","OAI Build") 
            | summarize by DCShortCode, ProjectName, Tranche, 
                  IST_L2Milestone = "IST Complete", ProjectType, 
                  IST_TaskStartDate = ISTDate, 
                  IST_TaskFinishDate = ISTDate
        )
        on $left.ProjectName == $right.ProjectName and $left.Tranche == $right.Tranche
        | project-away DCShortCode1, ProjectName1, ProjectType1, Tranche1  
        | extend IST_2_CR = case
          (
              IFP_TaskFinishDate <= ago(1d) and CS_TaskStartDate  <= ago(1d) 
                and FS_TaskStartDate <= ago(1d) and IST_TaskStartDate <= ago(1d) 
                and CR_TaskStartDate > ago(1d),  1, 
                0
          ),
          FS_2_CR = case
          (
              IFP_TaskFinishDate <= ago(1d) and CS_TaskStartDate  <= ago(1d)  
                and FS_TaskStartDate <= ago(1d) and IST_TaskStartDate > ago(1d)  
                and CR_TaskStartDate > ago(1d),  1, 
                0
          ),
          CS_2_CR = case
          (
              IFP_TaskFinishDate <= ago(1d) and CS_TaskStartDate  <= ago(1d)  
                and FS_TaskStartDate  > ago(1d) and IST_TaskStartDate > ago(1d)  
                and CR_TaskStartDate > ago(1d),  1, 
                0
          ),
          IFP_2_CR = case
          (
              IFP_TaskFinishDate <= ago(1d) and CS_TaskStartDate  > ago(1d) 
                and FS_TaskStartDate  > ago(1d) and IST_TaskStartDate > ago(1d) 
                and CR_TaskStartDate > ago(1d),  1, 
                0
          )
        | where IFP_2_CR + CS_2_CR + FS_2_CR + IST_2_CR == 1
        ''',
        
        'IFP_CS_FS_IST_CR_Duration' : 
        '''
        let CRFullSet =  
        (
            DCEPAllMilestonesCurrent
            | where ProjectType in ("Build","Build PH","OAI Build") 
            | summarize by 
                  DCShortCode, ProjectName, ProjectType, Tranche, L2Milestone = "Colo Ready", 
                  CR_TaskStartDate = ColoReadyDate, CR_TaskFinishDate = ColoReadyDate
        ); 
        let ISTFullSet = 
        (
            DCEPAllMilestonesCurrent 
            | where ProjectType in ("Build","Build PH","OAI Build") 
            | summarize by 
                  DCShortCode, ProjectName, ProjectType, Tranche, L2Milestone = "IST Complete",  
                  IST_TaskStartDate = ISTDate, IST_TaskFinishDate = ISTDate
        ); 
        let FSFullSet = 
        (
          EstimatedFoundationStart
          | where ProjectType in ("Build","Build PH","OAI Build") 
          | summarize by 
                DCShortCode, ProjectName, ProjectType, Tranche = tostring(Tranche), 
                L2Milestone="Foundation", 
                FS_TaskStartDate = Foudation_TaskStartDate, 
                FS_TaskFinishDate = Foudation_TaskFinishDate
        );
        let CSFullSet = 
        (
          DCEPAllMilestonesCurrent
          | where ProjectType in ("Build","Build PH","OAI Build") 
          | summarize by ProjectName, Tranche
          | join kind = leftouter  
          (
            DCEPAllMilestonesCurrent 
            | where Tranche == 1 and ProjectType in ("Build","Build PH","OAI Build")
            | summarize by 
                DCShortCode, ProjectName,Tranche, L2Milestone = "Construction Start", 
                ProjectType, CS_TaskStartDate = ConstructionDate, 
                CS_TaskFinishDate = ConstructionDate
          ) 
          on $left.ProjectName == $right.ProjectName 
          | project-away ProjectName1, Tranche1
          | where isnotempty(CS_TaskFinishDate)
        );
        let IFPFullSet = 
        (
          DCEPAllMilestonesCurrent
          | where ProjectType in ("Build","Build PH","OAI Build") 
          | summarize by ProjectName, Tranche
          | join kind = leftouter  
          (
            DCEPAllMilestonesCurrent 
            | where Tranche == 1 and ProjectType in ("Build","Build PH","OAI Build") 
            | summarize by DCShortCode, ProjectName,Tranche, L2Milestone = "Design IFP", ProjectType, 
                           IFP_TaskStartDate = DesignIFP, IFP_TaskFinishDate = DesignIFP
          )
          on $left.ProjectName == $right.ProjectName 
          | project-away ProjectName1, Tranche1
        );         
        CRFullSet        
        | join kind= leftouter ISTFullSet 
        on $left.ProjectName == $right.ProjectName and $left.Tranche == $right.Tranche 
        | extend ist_cr_duration = datetime_diff("day",CR_TaskFinishDate, IST_TaskFinishDate)
        | project-away DCShortCode1, ProjectType1, ProjectName1, Tranche1, L2Milestone1
        | join kind= leftouter (FSFullSet) 
        on $left.ProjectName == $right.ProjectName and $left.Tranche == $right.Tranche
        | extend fs_cr_duration = datetime_diff("day", CR_TaskFinishDate, FS_TaskStartDate)
        | project-away DCShortCode1, ProjectType1, ProjectName1, Tranche1, L2Milestone1
        | join kind= leftouter (CSFullSet) 
        on $left.ProjectName == $right.ProjectName and $left.Tranche == $right.Tranche
        | extend cs_cr_duration = datetime_diff("day", CR_TaskFinishDate, CS_TaskFinishDate)
        | project-away DCShortCode1, ProjectType1, ProjectName1, Tranche1, L2Milestone1
        | join kind = inner (IFPFullSet) 
        on $left.ProjectName == $right.ProjectName and $left.ProjectType == $right.ProjectType and $left.Tranche == $right.Tranche 
        | extend ifp_cr_duration = datetime_diff("day", CR_TaskFinishDate, IFP_TaskFinishDate)
        | project-away DCShortCode1, ProjectType1, ProjectName1, Tranche1, L2Milestone1
        | order by DCShortCode asc, ProjectType, Tranche asc        
        ''',
        
        'IFP_CS_FS_IST_CR_p5080_min_max' : 
        '''
        let FY = 
          iff(
              monthofyear(ago(0d)) > 6, 
              datetime_part("year", ago(0d)) + 1, 
              datetime_part("year", ago(0d))
            ); 
        let FY_Startdate = strcat(FY - 3, "-07-01"); 
        let FY_Enddate = strcat(FY - 1, "-06-30"); 
        let CRFullSet = DCEPAllMilestonesCurrent 
        | where ProjectStatus == "Complete"  
        and ProjectType in ("Build","Build PH","OAI Build") 
        and ColoReadyDate <= todatetime(FY_Enddate) 
        and ColoReadyDate > todatetime(FY_Startdate) 
        | summarize min(ColoReadyDate) 
          by DCShortCode, ProjectType, ProjectName, Tranche, Region, ColoReadyDate;         
        let IFPFullSet =  DCEPAllMilestonesCurrent
        | where ProjectType in ("Build","Build PH","OAI Build") 
        | summarize by ProjectName, Tranche
        | join kind = leftouter  
        (
            DCEPAllMilestonesCurrent 
            | where Tranche == 1 and ProjectType in ("Build","Build PH","OAI Build") 
            | summarize by DCShortCode, ProjectName,Tranche, Region, ProjectType, 
              IFP_TaskStartDate = DesignIFP, IFP_TaskFinishDate = DesignIFP
        )
        on $left.ProjectName == $right.ProjectName 
        | project-away ProjectName1, Tranche1
        | where isnotempty(IFP_TaskStartDate);
        let IFP_CR_Duration = IFPFullSet 
        | join kind = inner CRFullSet on $left.DCShortCode == $right.DCShortCode 
          and $left.ProjectType == $right.ProjectType  and $left.Tranche == $right.Tranche 
        | project DCShortCode, ProjectType, Tranche, IFP_TaskStartDate, ColoReadyDate, 
          duration = datetime_diff("day",ColoReadyDate, IFP_TaskStartDate)
        | extend leadtime = datetime_diff("day",ColoReadyDate, IFP_TaskStartDate)*1.0 
        | order by DCShortCode, ProjectType, Tranche asc        
        | extend ID="IFPCR"
        | where duration  > 0;       
        let IFP_CR_Outlier = IFP_CR_Duration 
        | summarize P75 = percentiles(leadtime,75),P25 = percentiles(leadtime,25) by Tranche
        | extend IQR = P75-P25 
        | extend Upper_Whisker = P75+1.5*IQR ,Lower_Whisker = P25-1.5*IQR 
        | extend ID="IFPCR"; 
        let IFP_CR = IFP_CR_Duration 
        | join kind = leftouter IFP_CR_Outlier on $left.ID == $right.ID and $left.Tranche == $right.Tranche
        | extend Outlier = 
        iff(leadtime >Upper_Whisker or leadtime < Lower_Whisker,"Outlier","Not Outlier") 
        | where Outlier != "Outlier"; 
        let CSFullSet = DCEPAllMilestonesCurrent
        | where ProjectType in ("Build","Build PH","OAI Build") 
        | summarize by ProjectName, Tranche
        | join kind = leftouter 
        (
            DCEPAllMilestonesCurrent 
            | where Tranche == 1 and ProjectType in ("Build","Build PH","OAI Build") 
            | summarize by 
                  DCShortCode, ProjectName,Tranche, Region,
                  L2Milestone = "Construction Start", ProjectType, 
                  CS_TaskStartDate = ConstructionDate, 
                  CS_TaskFinishDate = ConstructionDate
        )
        on $left.ProjectName == $right.ProjectName 
        | project-away ProjectName1, Tranche1
        | where isnotempty(CS_TaskStartDate)
        | summarize CS_TaskStartDate = minif(CS_TaskStartDate, 
           L2Milestone in ("EarthWorks", "Construction Start")) by 
           DCShortCode, ProjectType, ProjectName, Tranche, Region;
        let CS_CR_Duration = CSFullSet 
        | join kind = inner CRFullSet 
        on $left.DCShortCode == $right.DCShortCode and $left.ProjectType == $right.ProjectType and $left.Tranche == $right.Tranche
        | project DCShortCode, ProjectType, Tranche, CS_TaskStartDate, ColoReadyDate, 
          duration = datetime_diff("day",ColoReadyDate, CS_TaskStartDate) 
        | extend leadtime = datetime_diff("day",ColoReadyDate, CS_TaskStartDate)*1.0 
        | order by DCShortCode asc | extend ID="CSCR"| where duration  > 0; 
        let CS_CR_Outlier = CS_CR_Duration 
        | summarize P75 = percentiles(leadtime,75), P25 = percentiles(leadtime,25) by Tranche
        | extend IQR = P75-P25 
        | extend Upper_Whisker = P75+1.5*IQR ,Lower_Whisker = P25-1.5*IQR 
        | extend ID="CSCR"; 
        let CS_CR = CS_CR_Duration 
        | join kind = leftouter CS_CR_Outlier on $left.ID == $right.ID and $left.Tranche == $right.Tranche
        | extend Outlier = iff
        (
            leadtime >Upper_Whisker or leadtime < Lower_Whisker,"Outlier","Not Outlier"
        ) 
        | where Outlier != "Outlier";                
        let FSFullSet =
        EstimatedFoundationStart
        | where ProjectType in ("Build","Build PH","OAI Build")
        | summarize by DCShortCode, ProjectType, ProjectName, 
          Tranche = tostring(Tranche),Region,FS_TaskStartDate =Foudation_TaskStartDate;        
        let FS_CR_Duration = 
        FSFullSet 
        | join kind = inner CRFullSet 
        on $left.DCShortCode == $right.DCShortCode and $left.ProjectType == $right.ProjectType and $left.Tranche == $right.Tranche 
        | project DCShortCode, Tranche, FS_TaskStartDate, ColoReadyDate, 
          duration = datetime_diff("day",ColoReadyDate, FS_TaskStartDate) 
        | extend leadtime = datetime_diff("day",ColoReadyDate, FS_TaskStartDate)*1.0 
        | order by DCShortCode, Tranche asc 
        | extend ID="FSCR"
        | where duration  > 0;        
        let FS_CR_Outlier = FS_CR_Duration 
        | summarize P75 = percentiles(leadtime,75),P25 = percentiles(leadtime,25) by Tranche
        | extend IQR = P75-P25 
        | extend Upper_Whisker = P75+1.5*IQR ,Lower_Whisker = P25-1.5*IQR 
        | extend ID="FSCR"; 
        let FS_CR = 
        FS_CR_Duration 
        | join kind = leftouter FS_CR_Outlier on $left.ID == $right.ID and $left.Tranche == $right.Tranche
        | extend Outlier = iff(
            leadtime >Upper_Whisker or leadtime < Lower_Whisker,"Outlier","Not Outlier"
            ) 
        | where Outlier != "Outlier";        
        let ISTFullSet = DCEPAllMilestonesCurrent 
        | where ProjectStatus == "Complete" 
          and ProjectType in ("Build","Build PH","OAI Build") 
          and ColoReadyDate <= todatetime(FY_Enddate) 
          and ColoReadyDate > todatetime(FY_Startdate) 
        | summarize min(ColoReadyDate) by 
          DCShortCode, ProjectType, Tranche, ProjectName, Region, ISTDate; 
        let IST_CR_Duration = ISTFullSet 
        | join kind = inner CRFullSet 
        on $left.DCShortCode == $right.DCShortCode and $left.ProjectType == $right.ProjectType and $left.Tranche == $right.Tranche
        | project DCShortCode, ProjectType, Tranche, ISTDate, ColoReadyDate, 
        duration = datetime_diff("day",ColoReadyDate, ISTDate) 
        | extend leadtime = datetime_diff("day",ColoReadyDate, ISTDate)*1.0 
        | order by DCShortCode asc | extend ID="ISTCR"
        | where duration  > 0; 
        let IST_CR_Outlier = IST_CR_Duration 
        | summarize P75 = percentiles(leadtime,75),P25 = percentiles(leadtime,25) by Tranche
        | extend IQR = P75-P25 
        | extend Upper_Whisker = P75+1.5*IQR ,Lower_Whisker = P25-1.5*IQR 
        | extend ID="ISTCR"; 
        let IST_CR = IST_CR_Duration 
        | join kind = leftouter IST_CR_Outlier on $left.ID == $right.ID and $left.Tranche == $right.Tranche
        | extend Outlier = iff(
            leadtime >Upper_Whisker or leadtime < Lower_Whisker,"Outlier","Not Outlier"
            ) 
        | where Outlier != "Outlier";      
        let IFP_CR_p5080_min_max = IFP_CR 
        | summarize 
            IFP_CR_percentile_duration_50 = percentiles(duration, 50), 
            IFP_CR_percentile_duration_80 = percentiles(duration, 80), 
            IFP_CR_duration_min = min(duration), 
            IFP_CR_duration_max = max(duration) 
            by Tranche;
        let CS_CR_p5080_min_max = CS_CR 
        | summarize 
            CS_CR_percentile_duration_50 = percentiles(duration, 50), 
            CS_CR_percentile_duration_80 = percentiles(duration, 80), 
            CS_CR_duration_min = min(duration), 
            CS_CR_duration_max = max(duration) 
            by Tranche;
        let FS_CR_p5080_min_max = FS_CR 
        | summarize 
            FS_CR_percentile_duration_50 = percentiles(duration, 50), 
            FS_CR_percentile_duration_80 = percentiles(duration, 80), 
            FS_CR_duration_min = min(duration), 
            FS_CR_duration_max = max(duration) 
            by Tranche;
        let IST_CR_p5080_min_max = IST_CR 
        | summarize 
            IST_CR_percentile_duration_50 = percentiles(duration, 50), 
            IST_CR_percentile_duration_80 = percentiles(duration, 80), 
            IST_CR_duration_min = min(duration), 
            IST_CR_duration_max = max(duration) 
            by Tranche;
        IFP_CR_p5080_min_max
        | join kind = leftouter CS_CR_p5080_min_max
        on $left.Tranche == $right.Tranche
        | join kind = leftouter FS_CR_p5080_min_max
        on $left.Tranche == $right.Tranche
        | join kind = leftouter IST_CR_p5080_min_max
        on $left.Tranche == $right.Tranche
        | order by Tranche asc
         | project-away Tranche1, Tranche2, Tranche3;
        '''
        };
    
    def get_duration_query(self):
        return self.duration;

    def query_kusto(self, query): 
        response = self.kusto_client.query(query);
        result = response.reset_index();         
        return result;

    def query_static_data(self):
        self.data = {};
        query = self.query['IFP_CS_FS_IST_CR_Tranche_List'];
        response = self.kusto_client.query(query);
        result = response.reset_index();
        self.data['IFP_CS_FS_IST_CR_Tranche_List'] = result;

        query = self.query['IFP_CS_FS_IST_CR_Duration'];
        response = self.kusto_client.query(query);
        result = response.reset_index();
        self.data['IFP_CS_FS_IST_CR_Duration'] = result;

        query = self.query['IFP_CS_FS_IST_CR_p5080_min_max'];
        response = self.kusto_client.query(query);
        result = response.reset_index();
        self.data['IFP_CS_FS_IST_CR_p5080_min_max'] = result;

        return self.data;

from asyncio.windows_events import NULL
import numpy as np
import os
import random
import pandas as pd
from time import time;

databaseConn = DatabaseConnection({'server' : 'eppmreportingdev.database.windows.net', 'database' :'DCEPDev'});
databaseConn.execute('DELETE FROM [MonteCarlo].[SimulationResult_HM]')
client = DCEPKustoData();
kusto_data = client.query_static_data();
N = 100000
stages = 1

project_tranches = kusto_data['IFP_CS_FS_IST_CR_Tranche_List'];
#print(project_tranches);

durations = kusto_data['IFP_CS_FS_IST_CR_Duration'];
#print(duration);

p5080_min_max = kusto_data['IFP_CS_FS_IST_CR_p5080_min_max'];
#print(p5080_min_max);

for index, project_tranche in project_tranches.iterrows():
    print('Project Tranche = ');
    print(project_tranche);
    print('p5080_min_max = ');
    print(p5080_min_max[p5080_min_max['Tranche'] ==  project_tranche['Tranche']]);
    print('Duration = ');
    print(durations[(durations['ProjectName'] == project_tranche['ProjectName']) & (durations['Tranche'] == project_tranche['Tranche'])]);
    stages = 1;
    T = np.empty(shape=(N, stages + 1));
    TaskTimes=[];
    TotalTime=[];
    Lh=[];
    duration = 0
    result = pd.DataFrame
    tasktime = []; 
    schedule_type = '';

    if project_tranche['IFP_2_CR'] == 1 :
        p50 = p5080_min_max[p5080_min_max['Tranche'] ==  project_tranche['Tranche']]['IFP_CR_percentile_duration_50'].values[0];
        p80 = p5080_min_max[p5080_min_max['Tranche'] ==  project_tranche['Tranche']]['IFP_CR_percentile_duration_80'].values[0];
        min = p5080_min_max[p5080_min_max['Tranche'] ==  project_tranche['Tranche']]['IFP_CR_duration_min'].values[0];
        max = p5080_min_max[p5080_min_max['Tranche'] ==  project_tranche['Tranche']]['IFP_CR_duration_max'].values[0];
        duration = durations[(durations['ProjectName'] == project_tranche['ProjectName']) & (durations['Tranche'] == project_tranche['Tranche'])]['ifp_cr_duration'].values[0];
        schedule_type = 'IFP_2_CR';
    elif project_tranche['CS_2_CR'] == 1 :
        p50 = p5080_min_max[p5080_min_max['Tranche'] ==  project_tranche['Tranche']]['CS_CR_percentile_duration_50'].values[0];
        p80 = p5080_min_max[p5080_min_max['Tranche'] ==  project_tranche['Tranche']]['CS_CR_percentile_duration_80'].values[0];
        min = p5080_min_max[p5080_min_max['Tranche'] ==  project_tranche['Tranche']]['CS_CR_duration_min'].values[0];
        max = p5080_min_max[p5080_min_max['Tranche'] ==  project_tranche['Tranche']]['CS_CR_duration_max'].values[0];
        duration = durations[(durations['ProjectName'] == project_tranche['ProjectName']) & (durations['Tranche'] == project_tranche['Tranche'])]['cs_cr_duration'].values[0];
        schedule_type = 'CS_2_CR';
    elif project_tranche['FS_2_CR'] == 1 :
        p50 = p5080_min_max[p5080_min_max['Tranche'] ==  project_tranche['Tranche']]['FS_CR_percentile_duration_50'].values[0];
        p80 = p5080_min_max[p5080_min_max['Tranche'] ==  project_tranche['Tranche']]['FS_CR_percentile_duration_80'].values[0];
        min = p5080_min_max[p5080_min_max['Tranche'] ==  project_tranche['Tranche']]['FS_CR_duration_min'].values[0];
        max = p5080_min_max[p5080_min_max['Tranche'] ==  project_tranche['Tranche']]['FS_CR_duration_max'].values[0];
        duration = durations[(durations['ProjectName'] == project_tranche['ProjectName']) & (durations['Tranche'] == project_tranche['Tranche'])]['fs_cr_duration'].values[0];
        schedule_type = 'FS_2_CR';
    elif project_tranche['IST_2_CR'] == 1 :
        p50 = p5080_min_max[p5080_min_max['Tranche'] ==  project_tranche['Tranche']]['IST_CR_percentile_duration_50'].values[0];
        p80 = p5080_min_max[p5080_min_max['Tranche'] ==  project_tranche['Tranche']]['IST_CR_percentile_duration_80'].values[0];
        min = p5080_min_max[p5080_min_max['Tranche'] ==  project_tranche['Tranche']]['IST_CR_duration_min'].values[0];
        max = p5080_min_max[p5080_min_max['Tranche'] ==  project_tranche['Tranche']]['IST_CR_duration_max'].values[0];
        duration = durations[(durations['ProjectName'] == project_tranche['ProjectName']) & (durations['Tranche'] == project_tranche['Tranche'])]['ist_cr_duration'].values[0];
        schedule_type = 'IST_2_CR';
    
    tasktime.append(min);
    tasktime.append(p50);
    tasktime.append(max);
    TaskTimes.append(tasktime);
    t0 = time();
    print('Time of start loop ', t0);
    for i in range(stages):
      Lh.append((TaskTimes[i][1]-TaskTimes[i][0]) / (TaskTimes[i][2]-TaskTimes[i][0]));

        #Lh running time result
    dt = time()-t0;
    print('Time to run Lh '+ 'dt_loop=%s' % round(dt, 10));

    t2 = time();
    print('Time of start CS to CR loop ', t2);
    for p in range(N):
      for i in range(stages):
        trand=random.random()
        if Lh[i] is not pd.NA:
          if (trand < Lh[i]):
            T[p][i] = TaskTimes[i][0] + np.sqrt(trand*(TaskTimes[i][1]-  TaskTimes[i][0])*(TaskTimes[i][2]-TaskTimes[i][0]));
            T[p][i+1] = duration;
          else:
            T[p][i] = TaskTimes[i][2] - np.sqrt((1-trand)*(TaskTimes[i][2] - TaskTimes[i][1]) * (TaskTimes[i][2]-TaskTimes[i][0]));
            T[p][i+1] = duration;
      TotalTime.append(T[p][0]);
    dt2_loop = time()-t2
    print('Time to run simulation loop '+ 'dt2_loop=%s' % round(dt2_loop, 10))

    Data = pd.DataFrame(T,columns=["MC_Simulation", "DCEP_Duration"]);
    pd.set_option("display.max_columns", None);
    df = Data.describe(percentiles=[.25, .50, .75,.95]).reset_index();
    df.rename(columns={"index": "statistics"}, inplace=True)
    df.insert(0,'ProjectName', [project_tranche["ProjectName"]] *len(df));
    df.insert(1,'Tranche', [project_tranche["Tranche"]] *len(df));
    df.insert(2,'ScheduleType', [schedule_type] *len(df));
    print(df);

    databaseConn.insert(df, table = '[MonteCarlo].[SimulationResult_HM]');

    #run simulation loop running time result
    dt_list = time()-t0
    print("TotalTime Size = " + str(len(TotalTime)));
    print('Project = '+ project_tranche["ProjectName"] + ', Tranche = '+ project_tranche["Tranche"]  + ', Time to run Bucket once '+ 'dt_loop=%s' % round(dt_list, 10));
    print('IFP_2_CR = '+ str(project_tranche["IFP_2_CR"]) + ', CS_2_CR = ' + str(project_tranche["CS_2_CR"]) + ', FS_2_CR = ' + str(project_tranche["FS_2_CR"]) + ', IST_2_CR = '+ str(project_tranche["IST_2_CR"]));
# Out:
# Project Tranche =
# index                                             0
# ProjectName                                   LON01
# Tranche                                           1
# DCShortCode                                   LON01
# Colo_Ready_L2Milestone                   Colo Ready
# ProjectType                                   Build
# CR_TaskStartDate          2025-06-24 00:00:00+00:00
# CR_TaskFinishDate         2025-06-24 00:00:00+00:00
# Design_IFP_Milestone                     Design IFP
# IFP_TaskStartDate         2022-02-18 00:00:00+00:00
# IFP_TaskFinishDate        2022-02-18 00:00:00+00:00
# CS_L2Milestone                   Construction Start
# CS_TaskStartDate          2023-01-31 00:00:00+00:00
# CS_TaskFinishDate         2023-01-31 00:00:00+00:00
# FS_L2Milestone                           Foundation
# FS_TaskStartDate          2023-02-21 08:00:00+00:00
# FS_TaskFinishDate         2024-02-23 17:00:00+00:00
# IST_L2Milestone                        IST Complete
# IST_TaskStartDate         2025-02-20 00:00:00+00:00
# IST_TaskFinishDate        2025-02-20 00:00:00+00:00
# IST_2_CR                                          0
# FS_2_CR                                           1
# CS_2_CR                                           0
# IFP_2_CR                                          0
# Name: 0, dtype: object
# p5080_min_max =
#    index Tranche  IFP_CR_percentile_duration_50  \
# 0      0       1                            713
#
#    IFP_CR_percentile_duration_80  IFP_CR_duration_min  IFP_CR_duration_max  \
# 0                           1159                  234                 1273
#
#    CS_CR_percentile_duration_50  CS_CR_percentile_duration_80  \
# 0                           688                           868
#
#    CS_CR_duration_min  CS_CR_duration_max  FS_CR_percentile_duration_50  \
# 0                 300                1239                           554
#
#    FS_CR_percentile_duration_80  FS_CR_duration_min  FS_CR_duration_max  \
# 0                           788                 443                1130
#
#    IST_CR_percentile_duration_50  IST_CR_percentile_duration_80  \
# 0                             60                             99
#
#    IST_CR_duration_min  IST_CR_duration_max
# 0                   14                  112
# Duration =
#      index DCShortCode ProjectName ProjectType Tranche L2Milestone  \
# 792    792       LON01       LON01       Build       1  Colo Ready
#
#              CR_TaskStartDate         CR_TaskFinishDate  \
# 792 2025-06-24 00:00:00+00:00 2025-06-24 00:00:00+00:00
#
#             IST_TaskStartDate        IST_TaskFinishDate  ist_cr_duration  \
# 792 2025-02-20 00:00:00+00:00 2025-02-20 00:00:00+00:00              124
#
#              FS_TaskStartDate         FS_TaskFinishDate  fs_cr_duration  \
# 792 2023-02-21 08:00:00+00:00 2024-02-23 17:00:00+00:00             854
#
#              CS_TaskStartDate         CS_TaskFinishDate  cs_cr_duration  \
# 792 2023-01-31 00:00:00+00:00 2023-01-31 00:00:00+00:00             875
#
#             IFP_TaskStartDate        IFP_TaskFinishDate  ifp_cr_duration
# 792 2022-02-18 00:00:00+00:00 2022-02-18 00:00:00+00:00             1222
# Time of start loop  1707496409.5109365
# Time to run Lh dt_loop=0.0
# Time of start CS to CR loop  1707496409.5109365
# Time to run simulation loop dt2_loop=1.0534079075
#   ProjectName Tranche ScheduleType statistics  MC_Simulation  DCEP_Duration
# 0       LON01       1      FS_2_CR      count  100000.000000       100000.0
# 1       LON01       1      FS_2_CR       mean     708.766853          854.0
# 2       LON01       1      FS_2_CR        std     150.585117            0.0
# 3       LON01       1      FS_2_CR        min     443.117284          854.0
# 4       LON01       1      FS_2_CR        25%     585.506091          854.0
# 5       LON01       1      FS_2_CR        50%     684.849859          854.0
# 6       LON01       1      FS_2_CR        75%     815.394005          854.0
# 7       LON01       1      FS_2_CR        95%     990.671100          854.0
# 8       LON01       1      FS_2_CR        max    1127.983573          854.0
#
#         INSERT INTO [MonteCarlo].[SimulationResult_HM]
#         (
#             [ProjectName],[Tranche],[ScheduleType],[statistics],[MC_Simulation],[DCEP_Duration]
#         )
#         VALUES(?,?,?,?,?,?)
#
# TotalTime Size = 100000
# Project = LON01, Tranche = 1, Time to run Bucket once dt_loop=1.433703661
# IFP_2_CR = 0, CS_2_CR = 0, FS_2_CR = 1, IST_2_CR = 0
# Project Tranche =
# index                                             1
# ProjectName                                   AMS13
# Tranche                                           1
# DCShortCode                                   AMS13
# Colo_Ready_L2Milestone                   Colo Ready
# ProjectType                                   Build
# CR_TaskStartDate          2024-05-31 00:00:00+00:00
# CR_TaskFinishDate         2024-05-31 00:00:00+00:00
# Design_IFP_Milestone                     Design IFP
# IFP_TaskStartDate         2019-11-08 00:00:00+00:00
# IFP_TaskFinishDate        2019-11-08 00:00:00+00:00
# CS_L2Milestone                   Construction Start
# CS_TaskStartDate          2021-11-01 00:00:00+00:00
# CS_TaskFinishDate         2021-11-01 00:00:00+00:00
# FS_L2Milestone                           Foundation
# FS_TaskStartDate          2022-04-22 08:00:00+00:00
# FS_TaskFinishDate         2022-05-20 17:00:00+00:00
# IST_L2Milestone                        IST Complete
# IST_TaskStartDate         2024-04-10 00:00:00+00:00
# IST_TaskFinishDate        2024-04-10 00:00:00+00:00
# IST_2_CR                                          0
# FS_2_CR                                           1
# CS_2_CR                                           0
# IFP_2_CR                                          0
# Name: 1, dtype: object
# p5080_min_max =
#    index Tranche  IFP_CR_percentile_duration_50  \
# 0      0       1                            713
#
#    IFP_CR_percentile_duration_80  IFP_CR_duration_min  IFP_CR_duration_max  \
# 0                           1159                  234                 1273
#
#    CS_CR_percentile_duration_50  CS_CR_percentile_duration_80  \
# 0                           688                           868
#
#    CS_CR_duration_min  CS_CR_duration_max  FS_CR_percentile_duration_50  \
# 0                 300                1239                           554
#
#    FS_CR_percentile_duration_80  FS_CR_duration_min  FS_CR_duration_max  \
# 0                           788                 443                1130
#
#    IST_CR_percentile_duration_50  IST_CR_percentile_duration_80  \
# 0                             60                             99
#
#    IST_CR_duration_min  IST_CR_duration_max
# 0                   14                  112
# Duration =
#     index DCShortCode ProjectName ProjectType Tranche L2Milestone  \
# 25     25       AMS13       AMS13       Build       1  Colo Ready
#
#             CR_TaskStartDate         CR_TaskFinishDate  \
# 25 2024-05-31 00:00:00+00:00 2024-05-31 00:00:00+00:00
#
#            IST_TaskStartDate        IST_TaskFinishDate  ist_cr_duration  \
# 25 2024-04-10 00:00:00+00:00 2024-04-10 00:00:00+00:00               51
#
#             FS_TaskStartDate         FS_TaskFinishDate  fs_cr_duration  \
# 25 2022-04-22 08:00:00+00:00 2022-05-20 17:00:00+00:00             770
#
#             CS_TaskStartDate         CS_TaskFinishDate  cs_cr_duration  \
# 25 2021-11-01 00:00:00+00:00 2021-11-01 00:00:00+00:00             942
#
#            IFP_TaskStartDate        IFP_TaskFinishDate  ifp_cr_duration
# 25 2019-11-08 00:00:00+00:00 2019-11-08 00:00:00+00:00             1666
# Time of start loop  1707496410.9762652
# Time to run Lh dt_loop=0.0
# Time of start CS to CR loop  1707496410.9762652
# Time to run simulation loop dt2_loop=1.4120686054
#   ProjectName Tranche ScheduleType statistics  MC_Simulation  DCEP_Duration
# 0       AMS13       1      FS_2_CR      count  100000.000000       100000.0
# 1       AMS13       1      FS_2_CR       mean     709.815897          770.0
# 2       AMS13       1      FS_2_CR        std     150.820282            0.0
# 3       AMS13       1      FS_2_CR        min     444.132349          770.0
# 4       AMS13       1      FS_2_CR        25%     585.095240          770.0
# 5       AMS13       1      FS_2_CR        50%     686.102502          770.0
# 6       AMS13       1      FS_2_CR        75%     817.814128          770.0
# 7       AMS13       1      FS_2_CR        95%     989.667842          770.0
# 8       AMS13       1      FS_2_CR        max    1126.776747          770.0
#
#         INSERT INTO [MonteCarlo].[SimulationResult_HM]
#         (
#             [ProjectName],[Tranche],[ScheduleType],[statistics],[MC_Simulation],[DCEP_Duration]
#         )
#         VALUES(?,?,?,?,?,?)
#
# TotalTime Size = 100000
# Project = AMS13, Tranche = 1, Time to run Bucket once dt_loop=1.7979235649
# IFP_2_CR = 0, CS_2_CR = 0, FS_2_CR = 1, IST_2_CR = 0
# Project Tranche =
# index                                             2
# ProjectName                                   AMS13
# Tranche                                           2
# DCShortCode                                   AMS13
# Colo_Ready_L2Milestone                   Colo Ready
# ProjectType                                   Build
# CR_TaskStartDate          2024-05-31 00:00:00+00:00
# CR_TaskFinishDate         2024-05-31 00:00:00+00:00
# Design_IFP_Milestone                     Design IFP
# IFP_TaskStartDate         2019-11-08 00:00:00+00:00
# IFP_TaskFinishDate        2019-11-08 00:00:00+00:00
# CS_L2Milestone                   Construction Start
# CS_TaskStartDate          2021-11-01 00:00:00+00:00
# CS_TaskFinishDate         2021-11-01 00:00:00+00:00
# FS_L2Milestone                           Foundation
# FS_TaskStartDate          2022-05-27 08:00:00+00:00
# FS_TaskFinishDate         2022-06-24 17:00:00+00:00
# IST_L2Milestone                        IST Complete
# IST_TaskStartDate         2024-05-15 00:00:00+00:00
# IST_TaskFinishDate        2024-05-15 00:00:00+00:00
# IST_2_CR                                          0
# FS_2_CR                                           1
# CS_2_CR                                           0
# IFP_2_CR                                          0
# Name: 2, dtype: object
# p5080_min_max =
#    index Tranche  IFP_CR_percentile_duration_50  \
# 1      1       2                            858
#
#    IFP_CR_percentile_duration_80  IFP_CR_duration_min  IFP_CR_duration_max  \
# 1                           1159                  558                 1295
#
#    CS_CR_percentile_duration_50  CS_CR_percentile_duration_80  \
# 1                           704                           800
#
#    CS_CR_duration_min  CS_CR_duration_max  FS_CR_percentile_duration_50  \
# 1                 306                1005                           576
#
#    FS_CR_percentile_duration_80  FS_CR_duration_min  FS_CR_duration_max  \
# 1                           718                 341                 858
#
#    IST_CR_percentile_duration_50  IST_CR_percentile_duration_80  \
# 1                             25                             33
#
#    IST_CR_duration_min  IST_CR_duration_max
# 1                    6                   78
# Duration =
#     index DCShortCode ProjectName ProjectType Tranche L2Milestone  \
# 26     26       AMS13       AMS13       Build       2  Colo Ready
#
#             CR_TaskStartDate         CR_TaskFinishDate  \
# 26 2024-05-31 00:00:00+00:00 2024-05-31 00:00:00+00:00
#
#            IST_TaskStartDate        IST_TaskFinishDate  ist_cr_duration  \
# 26 2024-05-15 00:00:00+00:00 2024-05-15 00:00:00+00:00               16
#
#             FS_TaskStartDate         FS_TaskFinishDate  fs_cr_duration  \
# 26 2022-05-27 08:00:00+00:00 2022-06-24 17:00:00+00:00             735
#
#             CS_TaskStartDate         CS_TaskFinishDate  cs_cr_duration  \
# 26 2021-11-01 00:00:00+00:00 2021-11-01 00:00:00+00:00             942
#
#            IFP_TaskStartDate        IFP_TaskFinishDate  ifp_cr_duration
# 26 2019-11-08 00:00:00+00:00 2019-11-08 00:00:00+00:00             1666
# Time of start loop  1707496412.859782
# Time to run Lh dt_loop=0.0008189678
# Time of start CS to CR loop  1707496412.860601
# Time to run simulation loop dt2_loop=1.4134933949
#   ProjectName Tranche ScheduleType statistics  MC_Simulation  DCEP_Duration
# 0       AMS13       2      FS_2_CR      count  100000.000000       100000.0
# 1       AMS13       2      FS_2_CR       mean     590.504876          735.0
# 2       AMS13       2      FS_2_CR        std     105.652480            0.0
# 3       AMS13       2      FS_2_CR        min     341.634006          735.0
# 4       AMS13       2      FS_2_CR        25%     513.758906          735.0
# 5       AMS13       2      FS_2_CR        50%     586.733336          735.0
# 6       AMS13       2      FS_2_CR        75%     665.744333          735.0
# 7       AMS13       2      FS_2_CR        95%     772.155892          735.0
# 8       AMS13       2      FS_2_CR        max     857.227128          735.0
#
#         INSERT INTO [MonteCarlo].[SimulationResult_HM]
#         (
#             [ProjectName],[Tranche],[ScheduleType],[statistics],[MC_Simulation],[DCEP_Duration]
#         )
#         VALUES(?,?,?,?,?,?)
#
# TotalTime Size = 100000
# Project = AMS13, Tranche = 2, Time to run Bucket once dt_loop=1.7956194878
# IFP_2_CR = 0, CS_2_CR = 0, FS_2_CR = 1, IST_2_CR = 0
# Project Tranche =
# index                                             3
# ProjectName                                   AMS13
# Tranche                                           3
# DCShortCode                                   AMS13
# Colo_Ready_L2Milestone                   Colo Ready
# ProjectType                                   Build
# CR_TaskStartDate          2024-07-11 00:00:00+00:00
# CR_TaskFinishDate         2024-07-11 00:00:00+00:00
# Design_IFP_Milestone                     Design IFP
# IFP_TaskStartDate         2019-11-08 00:00:00+00:00
# IFP_TaskFinishDate        2019-11-08 00:00:00+00:00
# CS_L2Milestone                   Construction Start
# CS_TaskStartDate          2021-11-01 00:00:00+00:00
# CS_TaskFinishDate         2021-11-01 00:00:00+00:00
# FS_L2Milestone                           Foundation
# FS_TaskStartDate          2022-07-08 08:00:00+00:00
# FS_TaskFinishDate         2022-08-05 17:00:00+00:00
# IST_L2Milestone                        IST Complete
# IST_TaskStartDate         2024-06-26 00:00:00+00:00
# IST_TaskFinishDate        2024-06-26 00:00:00+00:00
# IST_2_CR                                          0
# FS_2_CR                                           1
# CS_2_CR                                           0
# IFP_2_CR                                          0
# Name: 3, dtype: object
# p5080_min_max =
#    index Tranche  IFP_CR_percentile_duration_50  \
# 2      2       3                            929
#
#    IFP_CR_percentile_duration_80  IFP_CR_duration_min  IFP_CR_duration_max  \
# 2                           1335                  671                 1400
#
#    CS_CR_percentile_duration_50  CS_CR_percentile_duration_80  \
# 2                           821                          1143
#
#    CS_CR_duration_min  CS_CR_duration_max  FS_CR_percentile_duration_50  \
# 2                 715                1301                           631
#
#    FS_CR_percentile_duration_80  FS_CR_duration_min  FS_CR_duration_max  \
# 2                          1113                 444                1247
#
#    IST_CR_percentile_duration_50  IST_CR_percentile_duration_80  \
# 2                             18                             49
#
#    IST_CR_duration_min  IST_CR_duration_max
# 2                    8                   93
# Duration =
#     index DCShortCode ProjectName ProjectType Tranche L2Milestone  \
# 27     27       AMS13       AMS13       Build       3  Colo Ready
#
#             CR_TaskStartDate         CR_TaskFinishDate  \
# 27 2024-07-11 00:00:00+00:00 2024-07-11 00:00:00+00:00
#
#            IST_TaskStartDate        IST_TaskFinishDate  ist_cr_duration  \
# 27 2024-06-26 00:00:00+00:00 2024-06-26 00:00:00+00:00               15
#
#             FS_TaskStartDate         FS_TaskFinishDate  fs_cr_duration  \
# 27 2022-07-08 08:00:00+00:00 2022-08-05 17:00:00+00:00             734
#
#             CS_TaskStartDate         CS_TaskFinishDate  cs_cr_duration  \
# 27 2021-11-01 00:00:00+00:00 2021-11-01 00:00:00+00:00             983
#
#            IFP_TaskStartDate        IFP_TaskFinishDate  ifp_cr_duration
# 27 2019-11-08 00:00:00+00:00 2019-11-08 00:00:00+00:00             1707
# Time of start loop  1707496414.7025335
# Time to run Lh dt_loop=0.0
# Time of start CS to CR loop  1707496414.7025335
# Time to run simulation loop dt2_loop=1.5619945526
#   ProjectName Tranche ScheduleType statistics  MC_Simulation  DCEP_Duration
# 0       AMS13       3      FS_2_CR      count  100000.000000       100000.0
# 1       AMS13       3      FS_2_CR       mean     773.800029          734.0
# 2       AMS13       3      FS_2_CR        std     171.443091            0.0
# 3       AMS13       3      FS_2_CR        min     444.743483          734.0
# 4       AMS13       3      FS_2_CR        25%     637.734534          734.0
# 5       AMS13       3      FS_2_CR        50%     749.755333          734.0
# 6       AMS13       3      FS_2_CR        75%     895.372682          734.0
# 7       AMS13       3      FS_2_CR        95%    1088.621612          734.0
# 8       AMS13       3      FS_2_CR        max    1246.067897          734.0
#
#         INSERT INTO [MonteCarlo].[SimulationResult_HM]
#         (
#             [ProjectName],[Tranche],[ScheduleType],[statistics],[MC_Simulation],[DCEP_Duration]
#         )
#         VALUES(?,?,?,?,?,?)
#
# TotalTime Size = 100000
# Project = AMS13, Tranche = 3, Time to run Bucket once dt_loop=1.9578466415
# IFP_2_CR = 0, CS_2_CR = 0, FS_2_CR = 1, IST_2_CR = 0
# Project Tranche =
# index                                             4
# ProjectName                                   AMS14
# Tranche                                           1
# DCShortCode                                   AMS14
# Colo_Ready_L2Milestone                   Colo Ready
# ProjectType                                   Build
# CR_TaskStartDate          2024-05-16 00:00:00+00:00
# CR_TaskFinishDate         2024-05-16 00:00:00+00:00
# Design_IFP_Milestone                     Design IFP
# IFP_TaskStartDate         2019-11-08 00:00:00+00:00
# IFP_TaskFinishDate        2019-11-08 00:00:00+00:00
# CS_L2Milestone                   Construction Start
# CS_TaskStartDate          2021-11-01 00:00:00+00:00
# CS_TaskFinishDate         2021-11-01 00:00:00+00:00
# FS_L2Milestone                           Foundation
# FS_TaskStartDate          2022-05-17 08:00:00+00:00
# FS_TaskFinishDate         2022-07-29 17:00:00+00:00
# IST_L2Milestone                        IST Complete
# IST_TaskStartDate         2024-05-03 00:00:00+00:00
# IST_TaskFinishDate        2024-05-03 00:00:00+00:00
# IST_2_CR                                          0
# FS_2_CR                                           1
# CS_2_CR                                           0
# IFP_2_CR                                          0
# Name: 4, dtype: object
# p5080_min_max =
#    index Tranche  IFP_CR_percentile_duration_50  \
# 0      0       1                            713
#
#    IFP_CR_percentile_duration_80  IFP_CR_duration_min  IFP_CR_duration_max  \
# 0                           1159                  234                 1273
#
#    CS_CR_percentile_duration_50  CS_CR_percentile_duration_80  \
# 0                           688                           868
#
#    CS_CR_duration_min  CS_CR_duration_max  FS_CR_percentile_duration_50  \
# 0                 300                1239                           554
#
#    FS_CR_percentile_duration_80  FS_CR_duration_min  FS_CR_duration_max  \
# 0                           788                 443                1130
#
#    IST_CR_percentile_duration_50  IST_CR_percentile_duration_80  \
# 0                             60                             99
#
#    IST_CR_duration_min  IST_CR_duration_max
# 0                   14                  112
# Duration =
#     index DCShortCode ProjectName ProjectType Tranche L2Milestone  \
# 30     30       AMS14       AMS14       Build       1  Colo Ready
#
#             CR_TaskStartDate         CR_TaskFinishDate  \
# 30 2024-05-16 00:00:00+00:00 2024-05-16 00:00:00+00:00
#
#            IST_TaskStartDate        IST_TaskFinishDate  ist_cr_duration  \
# 30 2024-05-03 00:00:00+00:00 2024-05-03 00:00:00+00:00               13
#
#             FS_TaskStartDate         FS_TaskFinishDate  fs_cr_duration  \
# 30 2022-05-17 08:00:00+00:00 2022-07-29 17:00:00+00:00             730
#
#             CS_TaskStartDate         CS_TaskFinishDate  cs_cr_duration  \
# 30 2021-11-01 00:00:00+00:00 2021-11-01 00:00:00+00:00             927
#
#            IFP_TaskStartDate        IFP_TaskFinishDate  ifp_cr_duration
# 30 2019-11-08 00:00:00+00:00 2019-11-08 00:00:00+00:00             1651
# Time of start loop  1707496416.6985579
# Time to run Lh dt_loop=0.0
# Time of start CS to CR loop  1707496416.6985579
# Time to run simulation loop dt2_loop=1.8521311283
#   ProjectName Tranche ScheduleType statistics  MC_Simulation  DCEP_Duration
# 0       AMS14       1      FS_2_CR      count  100000.000000       100000.0
# 1       AMS14       1      FS_2_CR       mean     709.177287          730.0
# 2       AMS14       1      FS_2_CR        std     150.736035            0.0
# 3       AMS14       1      FS_2_CR        min     443.915489          730.0
# 4       AMS14       1      FS_2_CR        25%     585.450034          730.0
# 5       AMS14       1      FS_2_CR        50%     685.644560          730.0
# 6       AMS14       1      FS_2_CR        75%     815.852158          730.0
# 7       AMS14       1      FS_2_CR        95%     989.407327          730.0
# 8       AMS14       1      FS_2_CR        max    1126.698771          730.0
#
#         INSERT INTO [MonteCarlo].[SimulationResult_HM]
#         (
#             [ProjectName],[Tranche],[ScheduleType],[statistics],[MC_Simulation],[DCEP_Duration]
#         )
#         VALUES(?,?,?,?,?,?)
#
# TotalTime Size = 100000
# Project = AMS14, Tranche = 1, Time to run Bucket once dt_loop=2.2319350243
# IFP_2_CR = 0, CS_2_CR = 0, FS_2_CR = 1, IST_2_CR = 0
# Project Tranche =
# index                                             5
# ProjectName                                   AMS14
# Tranche                                           2
# DCShortCode                                   AMS14
# Colo_Ready_L2Milestone                   Colo Ready
# ProjectType                                   Build
# CR_TaskStartDate          2024-06-08 00:00:00+00:00
# CR_TaskFinishDate         2024-06-08 00:00:00+00:00
# Design_IFP_Milestone                     Design IFP
# IFP_TaskStartDate         2019-11-08 00:00:00+00:00
# IFP_TaskFinishDate        2019-11-08 00:00:00+00:00
# CS_L2Milestone                   Construction Start
# CS_TaskStartDate          2021-11-01 00:00:00+00:00
# CS_TaskFinishDate         2021-11-01 00:00:00+00:00
# FS_L2Milestone                           Foundation
# FS_TaskStartDate          2022-07-03 08:00:00+00:00
# FS_TaskFinishDate         2022-09-14 17:00:00+00:00
# IST_L2Milestone                        IST Complete
# IST_TaskStartDate         2024-06-19 00:00:00+00:00
# IST_TaskFinishDate        2024-06-19 00:00:00+00:00
# IST_2_CR                                          0
# FS_2_CR                                           1
# CS_2_CR                                           0
# IFP_2_CR                                          0
# Name: 5, dtype: object
# p5080_min_max =
#    index Tranche  IFP_CR_percentile_duration_50  \
# 1      1       2                            858
#
#    IFP_CR_percentile_duration_80  IFP_CR_duration_min  IFP_CR_duration_max  \
# 1                           1159                  558                 1295
#
#    CS_CR_percentile_duration_50  CS_CR_percentile_duration_80  \
# 1                           704                           800
#
#    CS_CR_duration_min  CS_CR_duration_max  FS_CR_percentile_duration_50  \
# 1                 306                1005                           576
#
#    FS_CR_percentile_duration_80  FS_CR_duration_min  FS_CR_duration_max  \
# 1                           718                 341                 858
#
#    IST_CR_percentile_duration_50  IST_CR_percentile_duration_80  \
# 1                             25                             33
#
#    IST_CR_duration_min  IST_CR_duration_max
# 1                    6                   78
# Duration =
#     index DCShortCode ProjectName ProjectType Tranche L2Milestone  \
# 31     31       AMS14       AMS14       Build       2  Colo Ready
#
#             CR_TaskStartDate         CR_TaskFinishDate  \
# 31 2024-06-08 00:00:00+00:00 2024-06-08 00:00:00+00:00
#
#            IST_TaskStartDate        IST_TaskFinishDate  ist_cr_duration  \
# 31 2024-06-19 00:00:00+00:00 2024-06-19 00:00:00+00:00              -11
#
#             FS_TaskStartDate         FS_TaskFinishDate  fs_cr_duration  \
# 31 2022-07-03 08:00:00+00:00 2022-09-14 17:00:00+00:00             706
#
#             CS_TaskStartDate         CS_TaskFinishDate  cs_cr_duration  \
# 31 2021-11-01 00:00:00+00:00 2021-11-01 00:00:00+00:00             950
#
#            IFP_TaskStartDate        IFP_TaskFinishDate  ifp_cr_duration
# 31 2019-11-08 00:00:00+00:00 2019-11-08 00:00:00+00:00             1674
# Time of start loop  1707496418.970423
# Time to run Lh dt_loop=0.0
# Time of start CS to CR loop  1707496418.970423
# Time to run simulation loop dt2_loop=1.5336277485
#   ProjectName Tranche ScheduleType statistics  MC_Simulation  DCEP_Duration
# 0       AMS14       2      FS_2_CR      count  100000.000000       100000.0
# 1       AMS14       2      FS_2_CR       mean     591.464297          706.0
# 2       AMS14       2      FS_2_CR        std     105.836839            0.0
# 3       AMS14       2      FS_2_CR        min     342.765846          706.0
# 4       AMS14       2      FS_2_CR        25%     515.228049          706.0
# 5       AMS14       2      FS_2_CR        50%     587.707143          706.0
# 6       AMS14       2      FS_2_CR        75%     667.077106          706.0
# 7       AMS14       2      FS_2_CR        95%     772.583415          706.0
# 8       AMS14       2      FS_2_CR        max     857.065048          706.0
#
#         INSERT INTO [MonteCarlo].[SimulationResult_HM]
#         (
#             [ProjectName],[Tranche],[ScheduleType],[statistics],[MC_Simulation],[DCEP_Duration]
#         )
#         VALUES(?,?,?,?,?,?)
#
# TotalTime Size = 100000
# Project = AMS14, Tranche = 2, Time to run Bucket once dt_loop=1.9045472145
# IFP_2_CR = 0, CS_2_CR = 0, FS_2_CR = 1, IST_2_CR = 0
# Project Tranche =
# index                                             6
# ProjectName                                   AMS14
# Tranche                                           3
# DCShortCode                                   AMS14
# Colo_Ready_L2Milestone                   Colo Ready
# ProjectType                                   Build
# CR_TaskStartDate          2024-08-10 00:00:00+00:00
# CR_TaskFinishDate         2024-08-10 00:00:00+00:00
# Design_IFP_Milestone                     Design IFP
# IFP_TaskStartDate         2019-11-08 00:00:00+00:00
# IFP_TaskFinishDate        2019-11-08 00:00:00+00:00
# CS_L2Milestone                   Construction Start
# CS_TaskStartDate          2021-11-01 00:00:00+00:00
# CS_TaskFinishDate         2021-11-01 00:00:00+00:00
# FS_L2Milestone                           Foundation
# FS_TaskStartDate          2022-07-24 08:00:00+00:00
# FS_TaskFinishDate         2022-10-05 17:00:00+00:00
# IST_L2Milestone                        IST Complete
# IST_TaskStartDate         2024-07-10 00:00:00+00:00
# IST_TaskFinishDate        2024-07-10 00:00:00+00:00
# IST_2_CR                                          0
# FS_2_CR                                           1
# CS_2_CR                                           0
# IFP_2_CR                                          0
# Name: 6, dtype: object
# p5080_min_max =
#    index Tranche  IFP_CR_percentile_duration_50  \
# 2      2       3                            929
#
#    IFP_CR_percentile_duration_80  IFP_CR_duration_min  IFP_CR_duration_max  \
# 2                           1335                  671                 1400
#
#    CS_CR_percentile_duration_50  CS_CR_percentile_duration_80  \
# 2                           821                          1143
#
#    CS_CR_duration_min  CS_CR_duration_max  FS_CR_percentile_duration_50  \
# 2                 715                1301                           631
#
#    FS_CR_percentile_duration_80  FS_CR_duration_min  FS_CR_duration_max  \
# 2                          1113                 444                1247
#
#    IST_CR_percentile_duration_50  IST_CR_percentile_duration_80  \
# 2                             18                             49
#
#    IST_CR_duration_min  IST_CR_duration_max
# 2                    8                   93
# Duration =
#     index DCShortCode ProjectName ProjectType Tranche L2Milestone  \
# 32     32       AMS14       AMS14       Build       3  Colo Ready
#
#             CR_TaskStartDate         CR_TaskFinishDate  \
# 32 2024-08-10 00:00:00+00:00 2024-08-10 00:00:00+00:00
#
#            IST_TaskStartDate        IST_TaskFinishDate  ist_cr_duration  \
# 32 2024-07-10 00:00:00+00:00 2024-07-10 00:00:00+00:00               31
#
#             FS_TaskStartDate         FS_TaskFinishDate  fs_cr_duration  \
# 32 2022-07-24 08:00:00+00:00 2022-10-05 17:00:00+00:00             748
#
#             CS_TaskStartDate         CS_TaskFinishDate  cs_cr_duration  \
# 32 2021-11-01 00:00:00+00:00 2021-11-01 00:00:00+00:00            1013
#
#            IFP_TaskStartDate        IFP_TaskFinishDate  ifp_cr_duration
# 32 2019-11-08 00:00:00+00:00 2019-11-08 00:00:00+00:00             1737
# Time of start loop  1707496420.9253724
# Time to run Lh dt_loop=0.0
# Time of start CS to CR loop  1707496420.9253724
# Time to run simulation loop dt2_loop=2.7268366814
#   ProjectName Tranche ScheduleType statistics  MC_Simulation  DCEP_Duration
# 0       AMS14       3      FS_2_CR      count  100000.000000       100000.0
# 1       AMS14       3      FS_2_CR       mean     774.565284          748.0
# 2       AMS14       3      FS_2_CR        std     171.764098            0.0
# 3       AMS14       3      FS_2_CR        min     445.098813          748.0
# 4       AMS14       3      FS_2_CR        25%     638.387407          748.0
# 5       AMS14       3      FS_2_CR        50%     750.089901          748.0
# 6       AMS14       3      FS_2_CR        75%     897.496588          748.0
# 7       AMS14       3      FS_2_CR        95%    1089.609944          748.0
# 8       AMS14       3      FS_2_CR        max    1244.907134          748.0
#
#         INSERT INTO [MonteCarlo].[SimulationResult_HM]
#         (
#             [ProjectName],[Tranche],[ScheduleType],[statistics],[MC_Simulation],[DCEP_Duration]
#         )
#         VALUES(?,?,?,?,?,?)
#
# TotalTime Size = 100000
# Project = AMS14, Tranche = 3, Time to run Bucket once dt_loop=3.1900987625
# IFP_2_CR = 0, CS_2_CR = 0, FS_2_CR = 1, IST_2_CR = 0
# Project Tranche =
# index                                             7
# ProjectName                                   SYD08
# Tranche                                           1
# DCShortCode                                   SYD08
# Colo_Ready_L2Milestone                   Colo Ready
# ProjectType                                   Build
# CR_TaskStartDate          2025-04-30 00:00:00+00:00
# CR_TaskFinishDate         2025-04-30 00:00:00+00:00
# Design_IFP_Milestone                     Design IFP
# IFP_TaskStartDate         2022-05-12 00:00:00+00:00
# IFP_TaskFinishDate        2022-05-12 00:00:00+00:00
# CS_L2Milestone                   Construction Start
# CS_TaskStartDate          2023-05-31 00:00:00+00:00
# CS_TaskFinishDate         2023-05-31 00:00:00+00:00
# FS_L2Milestone                           Foundation
# FS_TaskStartDate          2023-06-19 08:00:00+00:00
# FS_TaskFinishDate         2023-12-20 17:00:00+00:00
# IST_L2Milestone                        IST Complete
# IST_TaskStartDate         2024-12-02 00:00:00+00:00
# IST_TaskFinishDate        2024-12-02 00:00:00+00:00
# IST_2_CR                                          0
# FS_2_CR                                           1
# CS_2_CR                                           0
# IFP_2_CR                                          0
# Name: 7, dtype: object
# p5080_min_max =
#    index Tranche  IFP_CR_percentile_duration_50  \
# 0      0       1                            713
#
#    IFP_CR_percentile_duration_80  IFP_CR_duration_min  IFP_CR_duration_max  \
# 0                           1159                  234                 1273
#
#    CS_CR_percentile_duration_50  CS_CR_percentile_duration_80  \
# 0                           688                           868
#
#    CS_CR_duration_min  CS_CR_duration_max  FS_CR_percentile_duration_50  \
# 0                 300                1239                           554
#
#    FS_CR_percentile_duration_80  FS_CR_duration_min  FS_CR_duration_max  \
# 0                           788                 443                1130
#
#    IST_CR_percentile_duration_50  IST_CR_percentile_duration_80  \
# 0                             60                             99
#
#    IST_CR_duration_min  IST_CR_duration_max
# 0                   14                  112
# Duration =
#       index DCShortCode ProjectName ProjectType Tranche L2Milestone  \
# 1309   1309       SYD08       SYD08       Build       1  Colo Ready
#
#               CR_TaskStartDate         CR_TaskFinishDate  \
# 1309 2025-04-30 00:00:00+00:00 2025-04-30 00:00:00+00:00
#
#              IST_TaskStartDate        IST_TaskFinishDate  ist_cr_duration  \
# 1309 2024-12-02 00:00:00+00:00 2024-12-02 00:00:00+00:00              149
#
#               FS_TaskStartDate         FS_TaskFinishDate  fs_cr_duration  \
# 1309 2023-06-19 08:00:00+00:00 2023-12-20 17:00:00+00:00             681
#
#               CS_TaskStartDate         CS_TaskFinishDate  cs_cr_duration  \
# 1309 2023-05-31 00:00:00+00:00 2023-05-31 00:00:00+00:00             700
#
#              IFP_TaskStartDate        IFP_TaskFinishDate  ifp_cr_duration
# 1309 2022-05-12 00:00:00+00:00 2022-05-12 00:00:00+00:00             1084
# Time of start loop  1707496424.267839
# Time to run Lh dt_loop=0.0
# Time of start CS to CR loop  1707496424.267839
# Time to run simulation loop dt2_loop=1.8328039646
#   ProjectName Tranche ScheduleType statistics  MC_Simulation  DCEP_Duration
# 0       SYD08       1      FS_2_CR      count  100000.000000       100000.0
# 1       SYD08       1      FS_2_CR       mean     708.699033          681.0
# 2       SYD08       1      FS_2_CR        std     151.228667            0.0
# 3       SYD08       1      FS_2_CR        min     444.231018          681.0
# 4       SYD08       1      FS_2_CR        25%     584.105717          681.0
# 5       SYD08       1      FS_2_CR        50%     684.411400          681.0
# 6       SYD08       1      FS_2_CR        75%     815.939819          681.0
# 7       SYD08       1      FS_2_CR        95%     990.400131          681.0
# 8       SYD08       1      FS_2_CR        max    1128.397744          681.0
#
#         INSERT INTO [MonteCarlo].[SimulationResult_HM]
#         (
#             [ProjectName],[Tranche],[ScheduleType],[statistics],[MC_Simulation],[DCEP_Duration]
#         )
#         VALUES(?,?,?,?,?,?)
#
# TotalTime Size = 100000
# Project = SYD08, Tranche = 1, Time to run Bucket once dt_loop=2.2115373611
# IFP_2_CR = 0, CS_2_CR = 0, FS_2_CR = 1, IST_2_CR = 0
# Project Tranche =
# index                                             8
# ProjectName                                   SYD08
# Tranche                                           2
# DCShortCode                                   SYD08
# Colo_Ready_L2Milestone                   Colo Ready
# ProjectType                                   Build
# CR_TaskStartDate          2025-06-30 00:00:00+00:00
# CR_TaskFinishDate         2025-06-30 00:00:00+00:00
# Design_IFP_Milestone                     Design IFP
# IFP_TaskStartDate         2022-05-12 00:00:00+00:00
# IFP_TaskFinishDate        2022-05-12 00:00:00+00:00
# CS_L2Milestone                   Construction Start
# CS_TaskStartDate          2023-05-31 00:00:00+00:00
# CS_TaskFinishDate         2023-05-31 00:00:00+00:00
# FS_L2Milestone                           Foundation
# FS_TaskStartDate          2023-06-19 08:00:00+00:00
# FS_TaskFinishDate         2023-10-19 17:00:00+00:00
# IST_L2Milestone                        IST Complete
# IST_TaskStartDate         2025-02-03 00:00:00+00:00
# IST_TaskFinishDate        2025-02-03 00:00:00+00:00
# IST_2_CR                                          0
# FS_2_CR                                           1
# CS_2_CR                                           0
# IFP_2_CR                                          0
# Name: 8, dtype: object
# p5080_min_max =
#    index Tranche  IFP_CR_percentile_duration_50  \
# 1      1       2                            858
#
#    IFP_CR_percentile_duration_80  IFP_CR_duration_min  IFP_CR_duration_max  \
# 1                           1159                  558                 1295
#
#    CS_CR_percentile_duration_50  CS_CR_percentile_duration_80  \
# 1                           704                           800
#
#    CS_CR_duration_min  CS_CR_duration_max  FS_CR_percentile_duration_50  \
# 1                 306                1005                           576
#
#    FS_CR_percentile_duration_80  FS_CR_duration_min  FS_CR_duration_max  \
# 1                           718                 341                 858
#
#    IST_CR_percentile_duration_50  IST_CR_percentile_duration_80  \
# 1                             25                             33
#
#    IST_CR_duration_min  IST_CR_duration_max
# 1                    6                   78
# Duration =
#       index DCShortCode ProjectName ProjectType Tranche L2Milestone  \
# 1310   1310       SYD08       SYD08       Build       2  Colo Ready
#
#               CR_TaskStartDate         CR_TaskFinishDate  \
# 1310 2025-06-30 00:00:00+00:00 2025-06-30 00:00:00+00:00
#
#              IST_TaskStartDate        IST_TaskFinishDate  ist_cr_duration  \
# 1310 2025-02-03 00:00:00+00:00 2025-02-03 00:00:00+00:00              147
#
#               FS_TaskStartDate         FS_TaskFinishDate  fs_cr_duration  \
# 1310 2023-06-19 08:00:00+00:00 2023-10-19 17:00:00+00:00             742
#
#               CS_TaskStartDate         CS_TaskFinishDate  cs_cr_duration  \
# 1310 2023-05-31 00:00:00+00:00 2023-05-31 00:00:00+00:00             761
#
#              IFP_TaskStartDate        IFP_TaskFinishDate  ifp_cr_duration
# 1310 2022-05-12 00:00:00+00:00 2022-05-12 00:00:00+00:00             1145
# Time of start loop  1707496426.5178711
# Time to run Lh dt_loop=0.0125646591
# Time of start CS to CR loop  1707496426.5304358
# Time to run simulation loop dt2_loop=1.0510687828
#   ProjectName Tranche ScheduleType statistics  MC_Simulation  DCEP_Duration
# 0       SYD08       2      FS_2_CR      count  100000.000000       100000.0
# 1       SYD08       2      FS_2_CR       mean     591.568693          742.0
# 2       SYD08       2      FS_2_CR        std     105.688078            0.0
# 3       SYD08       2      FS_2_CR        min     342.501300          742.0
# 4       SYD08       2      FS_2_CR        25%     515.170581          742.0
# 5       SYD08       2      FS_2_CR        50%     588.263390          742.0
# 6       SYD08       2      FS_2_CR        75%     667.206937          742.0
# 7       SYD08       2      FS_2_CR        95%     772.001082          742.0
# 8       SYD08       2      FS_2_CR        max     857.828357          742.0
#
#         INSERT INTO [MonteCarlo].[SimulationResult_HM]
#         (
#             [ProjectName],[Tranche],[ScheduleType],[statistics],[MC_Simulation],[DCEP_Duration]
#         )
#         VALUES(?,?,?,?,?,?)
#
# TotalTime Size = 100000
# Project = SYD08, Tranche = 2, Time to run Bucket once dt_loop=1.4403841496
# IFP_2_CR = 0, CS_2_CR = 0, FS_2_CR = 1, IST_2_CR = 0
# Project Tranche =
# index                                             9
# ProjectName                                   AMS14
# Tranche                                           4
# DCShortCode                                   AMS14
# Colo_Ready_L2Milestone                   Colo Ready
# ProjectType                                   Build
# CR_TaskStartDate          2024-09-28 00:00:00+00:00
# CR_TaskFinishDate         2024-09-28 00:00:00+00:00
# Design_IFP_Milestone                     Design IFP
# IFP_TaskStartDate         2019-11-08 00:00:00+00:00
# IFP_TaskFinishDate        2019-11-08 00:00:00+00:00
# CS_L2Milestone                   Construction Start
# CS_TaskStartDate          2021-11-01 00:00:00+00:00
# CS_TaskFinishDate         2021-11-01 00:00:00+00:00
# FS_L2Milestone                           Foundation
# FS_TaskStartDate          2022-10-04 08:00:00+00:00
# FS_TaskFinishDate         2022-12-16 17:00:00+00:00
# IST_L2Milestone                        IST Complete
# IST_TaskStartDate         2024-09-20 00:00:00+00:00
# IST_TaskFinishDate        2024-09-20 00:00:00+00:00
# IST_2_CR                                          0
# FS_2_CR                                           1
# CS_2_CR                                           0
# IFP_2_CR                                          0
# Name: 9, dtype: object
# p5080_min_max =
#    index Tranche  IFP_CR_percentile_duration_50  \
# 3      3       4                            964
#
#    IFP_CR_percentile_duration_80  IFP_CR_duration_min  IFP_CR_duration_max  \
# 3                           1391                  705                 1443
#
#    CS_CR_percentile_duration_50  CS_CR_percentile_duration_80  \
# 3                           829                          1149
#
#    CS_CR_duration_min  CS_CR_duration_max  FS_CR_percentile_duration_50  \
# 3                 730                1357                           664
#
#    FS_CR_percentile_duration_80  FS_CR_duration_min  FS_CR_duration_max  \
# 3                          1248                 325                1346
#
#    IST_CR_percentile_duration_50  IST_CR_percentile_duration_80  \
# 3                             27                             56
#
#    IST_CR_duration_min  IST_CR_duration_max
# 3                    6                  120
# Duration =
#     index DCShortCode ProjectName ProjectType Tranche L2Milestone  \
# 33     33       AMS14       AMS14       Build       4  Colo Ready
#
#             CR_TaskStartDate         CR_TaskFinishDate  \
# 33 2024-09-28 00:00:00+00:00 2024-09-28 00:00:00+00:00
#
#            IST_TaskStartDate        IST_TaskFinishDate  ist_cr_duration  \
# 33 2024-09-20 00:00:00+00:00 2024-09-20 00:00:00+00:00                8
#
#             FS_TaskStartDate         FS_TaskFinishDate  fs_cr_duration  \
# 33 2022-10-04 08:00:00+00:00 2022-12-16 17:00:00+00:00             725
#
#             CS_TaskStartDate         CS_TaskFinishDate  cs_cr_duration  \
# 33 2021-11-01 00:00:00+00:00 2021-11-01 00:00:00+00:00            1062
#
#            IFP_TaskStartDate        IFP_TaskFinishDate  ifp_cr_duration
# 33 2019-11-08 00:00:00+00:00 2019-11-08 00:00:00+00:00             1786
# Time of start loop  1707496427.9940274
# Time to run Lh dt_loop=0.0
# Time of start CS to CR loop  1707496427.9940274
# Time to run simulation loop dt2_loop=1.019931078
#   ProjectName Tranche ScheduleType statistics  MC_Simulation  DCEP_Duration
# 0       AMS14       4      FS_2_CR      count  100000.000000       100000.0
# 1       AMS14       4      FS_2_CR       mean     778.231853          725.0
# 2       AMS14       4      FS_2_CR        std     212.535808            0.0
# 3       AMS14       4      FS_2_CR        min     327.020002          725.0
# 4       AMS14       4      FS_2_CR        25%     618.104959          725.0
# 5       AMS14       4      FS_2_CR        50%     755.890266          725.0
# 6       AMS14       4      FS_2_CR        75%     929.412928          725.0
# 7       AMS14       4      FS_2_CR        95%    1159.857381          725.0
# 8       AMS14       4      FS_2_CR        max    1344.832065          725.0
#
#         INSERT INTO [MonteCarlo].[SimulationResult_HM]
#         (
#             [ProjectName],[Tranche],[ScheduleType],[statistics],[MC_Simulation],[DCEP_Duration]
#         )
#         VALUES(?,?,?,?,?,?)
#
# TotalTime Size = 100000
# Project = AMS14, Tranche = 4, Time to run Bucket once dt_loop=1.4062614441
# IFP_2_CR = 0, CS_2_CR = 0, FS_2_CR = 1, IST_2_CR = 0
# Project Tranche =
# index                                            10
# ProjectName                                   AMS14
# Tranche                                           5
# DCShortCode                                   AMS14
# Colo_Ready_L2Milestone                   Colo Ready
# ProjectType                                   Build
# CR_TaskStartDate          2024-12-01 00:00:00+00:00
# CR_TaskFinishDate         2024-12-01 00:00:00+00:00
# Design_IFP_Milestone                     Design IFP
# IFP_TaskStartDate         2019-11-08 00:00:00+00:00
# IFP_TaskFinishDate        2019-11-08 00:00:00+00:00
# CS_L2Milestone                   Construction Start
# CS_TaskStartDate          2021-11-01 00:00:00+00:00
# CS_TaskFinishDate         2021-11-01 00:00:00+00:00
# FS_L2Milestone                           Foundation
# FS_TaskStartDate          2022-11-19 08:00:00+00:00
# FS_TaskFinishDate         2023-01-31 17:00:00+00:00
# IST_L2Milestone                        IST Complete
# IST_TaskStartDate         2024-11-05 00:00:00+00:00
# IST_TaskFinishDate        2024-11-05 00:00:00+00:00
# IST_2_CR                                          0
# FS_2_CR                                           1
# CS_2_CR                                           0
# IFP_2_CR                                          0
# Name: 10, dtype: object
# p5080_min_max =
#    index Tranche  IFP_CR_percentile_duration_50  \
# 4      4       5                           1129
#
#    IFP_CR_percentile_duration_80  IFP_CR_duration_min  IFP_CR_duration_max  \
# 4                           1381                  733                 1483
#
#    CS_CR_percentile_duration_50  CS_CR_percentile_duration_80  \
# 4                           842                          1223
#
#    CS_CR_duration_min  CS_CR_duration_max  FS_CR_percentile_duration_50  \
# 4                 738                1429                           690
#
#    FS_CR_percentile_duration_80  FS_CR_duration_min  FS_CR_duration_max  \
# 4                          1320                 392                1345
#
#    IST_CR_percentile_duration_50  IST_CR_percentile_duration_80  \
# 4                             20                             41
#
#    IST_CR_duration_min  IST_CR_duration_max
# 4                    7                  309
# Duration =
#     index DCShortCode ProjectName ProjectType Tranche L2Milestone  \
# 34     34       AMS14       AMS14       Build       5  Colo Ready
#
#             CR_TaskStartDate         CR_TaskFinishDate  \
# 34 2024-12-01 00:00:00+00:00 2024-12-01 00:00:00+00:00
#
#            IST_TaskStartDate        IST_TaskFinishDate  ist_cr_duration  \
# 34 2024-11-05 00:00:00+00:00 2024-11-05 00:00:00+00:00               26
#
#             FS_TaskStartDate         FS_TaskFinishDate  fs_cr_duration  \
# 34 2022-11-19 08:00:00+00:00 2023-01-31 17:00:00+00:00             743
#
#             CS_TaskStartDate         CS_TaskFinishDate  cs_cr_duration  \
# 34 2021-11-01 00:00:00+00:00 2021-11-01 00:00:00+00:00            1126
#
#            IFP_TaskStartDate        IFP_TaskFinishDate  ifp_cr_duration
# 34 2019-11-08 00:00:00+00:00 2019-11-08 00:00:00+00:00             1850
# Time of start loop  1707496429.4447935
# Time to run Lh dt_loop=0.0
# Time of start CS to CR loop  1707496429.4447935
# Time to run simulation loop dt2_loop=1.0542829037
#   ProjectName Tranche ScheduleType statistics  MC_Simulation  DCEP_Duration
# 0       AMS14       5      FS_2_CR      count  100000.000000       100000.0
# 1       AMS14       5      FS_2_CR       mean     808.437405          743.0
# 2       AMS14       5      FS_2_CR        std     199.277087            0.0
# 3       AMS14       5      FS_2_CR        min     393.702664          743.0
# 4       AMS14       5      FS_2_CR        25%     657.745413          743.0
# 5       AMS14       5      FS_2_CR        50%     785.361432          743.0
# 6       AMS14       5      FS_2_CR        75%     949.314777          743.0
# 7       AMS14       5      FS_2_CR        95%    1169.149826          743.0
# 8       AMS14       5      FS_2_CR        max    1343.159698          743.0
#
#         INSERT INTO [MonteCarlo].[SimulationResult_HM]
#         (
# ...
# 1                           704                           800
#
#    CS_CR_duration_min  CS_CR_duration_max  FS_CR_percentile_duration_50  \
# 1                 306                1005                           576
#
#    FS_CR_percentile_duration_80  FS_CR_duration_min  FS_CR_duration_max  \
# 1                           718                 341                 858
#
#    IST_CR_percentile_duration_50  IST_CR_percentile_duration_80  \
# 1                             25                             33
#
#    IST_CR_duration_min  IST_CR_duration_max
# 1                    6                   78
# Duration =
#       index DCShortCode ProjectName ProjectType Tranche L2Milestone  \
# 1094   1094       PHX74       PHX74       Build       2  Colo Ready
#
#               CR_TaskStartDate         CR_TaskFinishDate  \
# 1094 2026-12-19 00:00:00+00:00 2026-12-19 00:00:00+00:00
#
#              IST_TaskStartDate        IST_TaskFinishDate  ist_cr_duration  \
# 1094 2026-08-26 00:00:00+00:00 2026-08-26 00:00:00+00:00              115
#
#               FS_TaskStartDate         FS_TaskFinishDate  fs_cr_duration  \
# 1094 2024-12-18 08:00:00+00:00 2025-03-13 17:00:00+00:00             731
#
#               CS_TaskStartDate         CS_TaskFinishDate  cs_cr_duration  \
# 1094 2025-04-11 00:00:00+00:00 2025-04-11 00:00:00+00:00             617
#
#              IFP_TaskStartDate        IFP_TaskFinishDate  ifp_cr_duration
# 1094 2024-01-31 00:00:00+00:00 2024-01-31 00:00:00+00:00             1053
# Time of start loop  1707497523.1239977
# Time to run Lh dt_loop=0.0
# Time of start CS to CR loop  1707497523.1239977
# Time to run simulation loop dt2_loop=0.5819582939
#   ProjectName Tranche ScheduleType statistics  MC_Simulation  DCEP_Duration
# 0       PHX74       2     IFP_2_CR      count  100000.000000       100000.0
# 1       PHX74       2     IFP_2_CR       mean     903.661576         1053.0
# 2       PHX74       2     IFP_2_CR        std     151.183928            0.0
# 3       PHX74       2     IFP_2_CR        min     560.508554         1053.0
# 4       PHX74       2     IFP_2_CR        25%     793.128296         1053.0
# 5       PHX74       2     IFP_2_CR        50%     893.482225         1053.0
# 6       PHX74       2     IFP_2_CR        75%    1010.715706         1053.0
# 7       PHX74       2     IFP_2_CR        95%    1168.295963         1053.0
# 8       PHX74       2     IFP_2_CR        max    1292.390271         1053.0
#
#         INSERT INTO [MonteCarlo].[SimulationResult_HM]
#         (
#             [ProjectName],[Tranche],[ScheduleType],[statistics],[MC_Simulation],[DCEP_Duration]
#         )
#         VALUES(?,?,?,?,?,?)
#
# TotalTime Size = 100000
# Project = PHX74, Tranche = 2, Time to run Bucket once dt_loop=0.9463038445
# IFP_2_CR = 1, CS_2_CR = 0, FS_2_CR = 0, IST_2_CR = 0
# Project Tranche =
# index                                           585
# ProjectName                                   PHX74
# Tranche                                           3
# DCShortCode                                   PHX74
# Colo_Ready_L2Milestone                   Colo Ready
# ProjectType                                   Build
# CR_TaskStartDate          2027-01-18 00:00:00+00:00
# CR_TaskFinishDate         2027-01-18 00:00:00+00:00
# Design_IFP_Milestone                     Design IFP
# IFP_TaskStartDate         2024-01-31 00:00:00+00:00
# IFP_TaskFinishDate        2024-01-31 00:00:00+00:00
# CS_L2Milestone                   Construction Start
# CS_TaskStartDate          2025-04-11 00:00:00+00:00
# CS_TaskFinishDate         2025-04-11 00:00:00+00:00
# FS_L2Milestone                           Foundation
# FS_TaskStartDate          2025-01-17 08:00:00+00:00
# FS_TaskFinishDate         2025-04-12 17:00:00+00:00
# IST_L2Milestone                        IST Complete
# IST_TaskStartDate         2026-10-10 00:00:00+00:00
# IST_TaskFinishDate        2026-10-10 00:00:00+00:00
# IST_2_CR                                          0
# FS_2_CR                                           0
# CS_2_CR                                           0
# IFP_2_CR                                          1
# Name: 585, dtype: object
# p5080_min_max =
#    index Tranche  IFP_CR_percentile_duration_50  \
# 2      2       3                            929
#
#    IFP_CR_percentile_duration_80  IFP_CR_duration_min  IFP_CR_duration_max  \
# 2                           1335                  671                 1400
#
#    CS_CR_percentile_duration_50  CS_CR_percentile_duration_80  \
# 2                           821                          1143
#
#    CS_CR_duration_min  CS_CR_duration_max  FS_CR_percentile_duration_50  \
# 2                 715                1301                           631
#
#    FS_CR_percentile_duration_80  FS_CR_duration_min  FS_CR_duration_max  \
# 2                          1113                 444                1247
#
#    IST_CR_percentile_duration_50  IST_CR_percentile_duration_80  \
# 2                             18                             49
#
#    IST_CR_duration_min  IST_CR_duration_max
# 2                    8                   93
# Duration =
#       index DCShortCode ProjectName ProjectType Tranche L2Milestone  \
# 1095   1095       PHX74       PHX74       Build       3  Colo Ready
#
#               CR_TaskStartDate         CR_TaskFinishDate  \
# 1095 2027-01-18 00:00:00+00:00 2027-01-18 00:00:00+00:00
#
#              IST_TaskStartDate        IST_TaskFinishDate  ist_cr_duration  \
# 1095 2026-10-10 00:00:00+00:00 2026-10-10 00:00:00+00:00              100
#
#               FS_TaskStartDate         FS_TaskFinishDate  fs_cr_duration  \
# 1095 2025-01-17 08:00:00+00:00 2025-04-12 17:00:00+00:00             731
#
#               CS_TaskStartDate         CS_TaskFinishDate  cs_cr_duration  \
# 1095 2025-04-11 00:00:00+00:00 2025-04-11 00:00:00+00:00             647
#
#              IFP_TaskStartDate        IFP_TaskFinishDate  ifp_cr_duration
# 1095 2024-01-31 00:00:00+00:00 2024-01-31 00:00:00+00:00             1083
# Time of start loop  1707497524.117199
# Time to run Lh dt_loop=0.0
# Time of start CS to CR loop  1707497524.117199
# Time to run simulation loop dt2_loop=0.6283013821
#   ProjectName Tranche ScheduleType statistics  MC_Simulation  DCEP_Duration
# 0       PHX74       3     IFP_2_CR      count  100000.000000       100000.0
# 1       PHX74       3     IFP_2_CR       mean    1000.137462         1083.0
# 2       PHX74       3     IFP_2_CR        std     151.019103            0.0
# 3       PHX74       3     IFP_2_CR        min     671.362039         1083.0
# 4       PHX74       3     IFP_2_CR        25%     888.147896         1083.0
# 5       PHX74       3     IFP_2_CR        50%     986.484965         1083.0
# 6       PHX74       3     IFP_2_CR        75%    1107.128792         1083.0
# 7       PHX74       3     IFP_2_CR        95%    1269.133932         1083.0
# 8       PHX74       3     IFP_2_CR        max    1398.329656         1083.0
#
#         INSERT INTO [MonteCarlo].[SimulationResult_HM]
#         (
#             [ProjectName],[Tranche],[ScheduleType],[statistics],[MC_Simulation],[DCEP_Duration]
#         )
#         VALUES(?,?,?,?,?,?)
#
# TotalTime Size = 100000
# Project = PHX74, Tranche = 3, Time to run Bucket once dt_loop=0.9935252666
# IFP_2_CR = 1, CS_2_CR = 0, FS_2_CR = 0, IST_2_CR = 0
# Project Tranche =
# index                                           586
# ProjectName                                   PHX74
# Tranche                                           4
# DCShortCode                                   PHX74
# Colo_Ready_L2Milestone                   Colo Ready
# ProjectType                                   Build
# CR_TaskStartDate          2027-02-17 00:00:00+00:00
# CR_TaskFinishDate         2027-02-17 00:00:00+00:00
# Design_IFP_Milestone                     Design IFP
# IFP_TaskStartDate         2024-01-31 00:00:00+00:00
# IFP_TaskFinishDate        2024-01-31 00:00:00+00:00
# CS_L2Milestone                   Construction Start
# CS_TaskStartDate          2025-04-11 00:00:00+00:00
# CS_TaskFinishDate         2025-04-11 00:00:00+00:00
# FS_L2Milestone                           Foundation
# FS_TaskStartDate          2025-02-16 08:00:00+00:00
# FS_TaskFinishDate         2025-05-12 17:00:00+00:00
# IST_L2Milestone                        IST Complete
# IST_TaskStartDate         2026-11-24 00:00:00+00:00
# IST_TaskFinishDate        2026-11-24 00:00:00+00:00
# IST_2_CR                                          0
# FS_2_CR                                           0
# CS_2_CR                                           0
# IFP_2_CR                                          1
# Name: 586, dtype: object
# p5080_min_max =
#    index Tranche  IFP_CR_percentile_duration_50  \
# 3      3       4                            964
#
#    IFP_CR_percentile_duration_80  IFP_CR_duration_min  IFP_CR_duration_max  \
# 3                           1391                  705                 1443
#
#    CS_CR_percentile_duration_50  CS_CR_percentile_duration_80  \
# 3                           829                          1149
#
#    CS_CR_duration_min  CS_CR_duration_max  FS_CR_percentile_duration_50  \
# 3                 730                1357                           664
#
#    FS_CR_percentile_duration_80  FS_CR_duration_min  FS_CR_duration_max  \
# 3                          1248                 325                1346
#
#    IST_CR_percentile_duration_50  IST_CR_percentile_duration_80  \
# 3                             27                             56
#
#    IST_CR_duration_min  IST_CR_duration_max
# 3                    6                  120
# Duration =
#       index DCShortCode ProjectName ProjectType Tranche L2Milestone  \
# 1096   1096       PHX74       PHX74       Build       4  Colo Ready
#
#               CR_TaskStartDate         CR_TaskFinishDate  \
# 1096 2027-02-17 00:00:00+00:00 2027-02-17 00:00:00+00:00
#
#              IST_TaskStartDate        IST_TaskFinishDate  ist_cr_duration  \
# 1096 2026-11-24 00:00:00+00:00 2026-11-24 00:00:00+00:00               85
#
#               FS_TaskStartDate         FS_TaskFinishDate  fs_cr_duration  \
# 1096 2025-02-16 08:00:00+00:00 2025-05-12 17:00:00+00:00             731
#
#               CS_TaskStartDate         CS_TaskFinishDate  cs_cr_duration  \
# 1096 2025-04-11 00:00:00+00:00 2025-04-11 00:00:00+00:00             677
#
#              IFP_TaskStartDate        IFP_TaskFinishDate  ifp_cr_duration
# 1096 2024-01-31 00:00:00+00:00 2024-01-31 00:00:00+00:00             1113
# Time of start loop  1707497525.1262228
# Time to run Lh dt_loop=0.0
# Time of start CS to CR loop  1707497525.1262228
# Time to run simulation loop dt2_loop=0.5662438869
#   ProjectName Tranche ScheduleType statistics  MC_Simulation  DCEP_Duration
# 0       PHX74       4     IFP_2_CR      count  100000.000000       100000.0
# 1       PHX74       4     IFP_2_CR       mean    1037.371613         1113.0
# 2       PHX74       4     IFP_2_CR        std     152.970238            0.0
# 3       PHX74       4     IFP_2_CR        min     705.642419         1113.0
# 4       PHX74       4     IFP_2_CR        25%     923.146026         1113.0
# 5       PHX74       4     IFP_2_CR        50%    1022.764663         1113.0
# 6       PHX74       4     IFP_2_CR        75%    1145.490706         1113.0
# 7       PHX74       4     IFP_2_CR        95%    1309.795507         1113.0
# 8       PHX74       4     IFP_2_CR        max    1441.295358         1113.0
#
#         INSERT INTO [MonteCarlo].[SimulationResult_HM]
#         (
#             [ProjectName],[Tranche],[ScheduleType],[statistics],[MC_Simulation],[DCEP_Duration]
#         )
#         VALUES(?,?,?,?,?,?)
#
# TotalTime Size = 100000
# Project = PHX74, Tranche = 4, Time to run Bucket once dt_loop=0.9285857677
# IFP_2_CR = 1, CS_2_CR = 0, FS_2_CR = 0, IST_2_CR = 0
# Project Tranche =
# index                                           587
# ProjectName                                   PHX74
# Tranche                                           5
# DCShortCode                                   PHX74
# Colo_Ready_L2Milestone                   Colo Ready
# ProjectType                                   Build
# CR_TaskStartDate          2027-03-19 00:00:00+00:00
# CR_TaskFinishDate         2027-03-19 00:00:00+00:00
# Design_IFP_Milestone                     Design IFP
# IFP_TaskStartDate         2024-01-31 00:00:00+00:00
# IFP_TaskFinishDate        2024-01-31 00:00:00+00:00
# CS_L2Milestone                   Construction Start
# CS_TaskStartDate          2025-04-11 00:00:00+00:00
# CS_TaskFinishDate         2025-04-11 00:00:00+00:00
# FS_L2Milestone                           Foundation
# FS_TaskStartDate          2025-03-18 08:00:00+00:00
# FS_TaskFinishDate         2025-06-11 17:00:00+00:00
# IST_L2Milestone                        IST Complete
# IST_TaskStartDate         2027-01-08 00:00:00+00:00
# IST_TaskFinishDate        2027-01-08 00:00:00+00:00
# IST_2_CR                                          0
# FS_2_CR                                           0
# CS_2_CR                                           0
# IFP_2_CR                                          1
# Name: 587, dtype: object
# p5080_min_max =
#    index Tranche  IFP_CR_percentile_duration_50  \
# 4      4       5                           1129
#
#    IFP_CR_percentile_duration_80  IFP_CR_duration_min  IFP_CR_duration_max  \
# 4                           1381                  733                 1483
#
#    CS_CR_percentile_duration_50  CS_CR_percentile_duration_80  \
# 4                           842                          1223
#
#    CS_CR_duration_min  CS_CR_duration_max  FS_CR_percentile_duration_50  \
# 4                 738                1429                           690
#
#    FS_CR_percentile_duration_80  FS_CR_duration_min  FS_CR_duration_max  \
# 4                          1320                 392                1345
#
#    IST_CR_percentile_duration_50  IST_CR_percentile_duration_80  \
# 4                             20                             41
#
#    IST_CR_duration_min  IST_CR_duration_max
# 4                    7                  309
# Duration =
#       index DCShortCode ProjectName ProjectType Tranche L2Milestone  \
# 1097   1097       PHX74       PHX74       Build       5  Colo Ready
#
#               CR_TaskStartDate         CR_TaskFinishDate  \
# 1097 2027-03-19 00:00:00+00:00 2027-03-19 00:00:00+00:00
#
#              IST_TaskStartDate        IST_TaskFinishDate  ist_cr_duration  \
# 1097 2027-01-08 00:00:00+00:00 2027-01-08 00:00:00+00:00               70
#
#               FS_TaskStartDate         FS_TaskFinishDate  fs_cr_duration  \
# 1097 2025-03-18 08:00:00+00:00 2025-06-11 17:00:00+00:00             731
#
#               CS_TaskStartDate         CS_TaskFinishDate  cs_cr_duration  \
# 1097 2025-04-11 00:00:00+00:00 2025-04-11 00:00:00+00:00             707
#
#              IFP_TaskStartDate        IFP_TaskFinishDate  ifp_cr_duration
# 1097 2024-01-31 00:00:00+00:00 2024-01-31 00:00:00+00:00             1143
# Time of start loop  1707497526.0865672
# Time to run Lh dt_loop=0.0
# Time of start CS to CR loop  1707497526.0865672
# Time to run simulation loop dt2_loop=0.629042387
#   ProjectName Tranche ScheduleType statistics  MC_Simulation  DCEP_Duration
# 0       PHX74       5     IFP_2_CR      count  100000.000000       100000.0
# 1       PHX74       5     IFP_2_CR       mean    1115.290160         1143.0
# 2       PHX74       5     IFP_2_CR        std     153.322199            0.0
# 3       PHX74       5     IFP_2_CR        min     735.633769         1143.0
# 4       PHX74       5     IFP_2_CR        25%    1005.675890         1143.0
# 5       PHX74       5     IFP_2_CR        50%    1118.695032         1143.0
# 6       PHX74       5     IFP_2_CR        75%    1225.363986         1143.0
# 7       PHX74       5     IFP_2_CR        95%    1369.390428         1143.0
# 8       PHX74       5     IFP_2_CR        max    1481.969632         1143.0
#
#         INSERT INTO [MonteCarlo].[SimulationResult_HM]
#         (
#             [ProjectName],[Tranche],[ScheduleType],[statistics],[MC_Simulation],[DCEP_Duration]
#         )
#         VALUES(?,?,?,?,?,?)
#
# TotalTime Size = 100000
# Project = PHX74, Tranche = 5, Time to run Bucket once dt_loop=0.9910225868
# IFP_2_CR = 1, CS_2_CR = 0, FS_2_CR = 0, IST_2_CR = 0
